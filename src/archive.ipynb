# %%
# Öffnen der Wave-Datei
import wave

# Öffnen der Wave-Datei im Lesemodus
with wave.open('Pistole1.wav', 'rb') as wave_datei:
    # Extrahieren der Parameter der Wave-Datei
    frame_rate = wave_datei.getframerate()
    num_frames = wave_datei.getnframes()
    channels = wave_datei.getnchannels()
    sample_width = wave_datei.getsampwidth()

    print("Frame Rate:", frame_rate)
    print("Anzahl der Frames:", num_frames)
    print("Anzahl der Kanäle:", channels)
    print("Sample Width (Byte pro Sample):", sample_width)

    # Lesen der Wave-Daten
    wave_daten = wave_datei.readframes(num_frames)

# Nun kannst du die Wave-Daten weiter verarbeiten, je nachdem was du damit tun möchtest.
# Out:
# Frame Rate: 44100
# Anzahl der Frames: 16960
# Anzahl der Kanäle: 2
# Sample Width (Byte pro Sample): 2
# ...

# %%
array_wav = np.array(wave_daten) 
print(array_wav)
# Out:
# b'
# ...
